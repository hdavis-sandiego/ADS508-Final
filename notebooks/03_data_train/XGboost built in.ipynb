# %% [markdown]
# ### XGBOOST Forecasting

# %%
xgb_image_uri = sagemaker.image_uris.retrieve("xgboost", region="us-east-1", version="latest")

print(xgb_image_uri)
# Out:
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest

# %%
import boto3
import sagemaker
import csv
import pandas as pd
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.amazon.amazon_estimator import get_image_uri

# xgb_estimator = sagemaker.estimator.Estimator(
#     image_uri='811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#     role=sagemaker.get_execution_role(),
#     instance_count=1,
#     instance_type='ml.m5.large',
#     output_path=f's3://aurelia-resort-data/model_train/XGboost Forecast//output',
#     sagemaker_session=sagemaker_session,
#     framework_version='1.3-1'
# )

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)

# %%
container = get_image_uri(region_name=region, 
                          repo_name='xgboost', 
                          repo_version='latest')

xgb_estimator = sagemaker.estimator.Estimator(container,
                                              role=sagemaker.get_execution_role(),
                                              instance_count=1,
                                              instance_type='ml.m4.xlarge',
                                              output_path=f's3://aurelia-resort-data/model_train/XGboost Forecast//output',
                                              sagemaker_session=sagemaker_session,)

xgb_estimator.set_hyperparameters(max_depth=5,
                                  eta=0.2,
                                  gamma=4,
                                  min_child_weight=6,
                                  subsample=0.8,
                                  objective='reg:squarederror',
                                  num_round=100)

# xgb_estimator.fit(inputs={'train': train_data})
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Get train/test dataframes from S3

# %%
# !aws s3 cp --recursive s3://aurelia-resort-data/model_train/data_csv/ ./data
# Out:
# download: s3://aurelia-resort-data/model_train/data_csv/train.csv to data/train.csv
# download: s3://aurelia-resort-data/model_train/data_csv/test_nans.csv to data/test_nans.csv
# download: s3://aurelia-resort-data/model_train/data_csv/train_nans.csv to data/train_nans.csv
# download: s3://aurelia-resort-data/model_train/data_csv/test.csv to data/test.csv

# %%
train = pd.read_csv('data/train.csv',  header=None)
test = pd.read_csv('data/test.csv', header=None)

# %%
train.head()
# Out:
#             0                      1                           2  \
# 0        Date  TotalAirlineTripstoDC  TotalAirlinePassengerstoDC
# 1  2019-01-01                    435                   1326271.0
# 2  2019-02-01                    385                   1261292.0
# 3  2019-03-01                    422                   1668002.0
# 4  2019-04-01                    427                   1681832.0
#
#                         3                              4  \
# 0  TotalAmericanTravelers  PercentofAmericanswhoTraveled
# 1      265224073.85258028              81.44242073648299
# 2      266240835.73305443              81.77432628778035
# 3      265091945.14415318              81.79908504520232
# 4      264062598.41495603              81.35434739932987
#
#                        5          6             7
# 0  TotalTripsbyAmericans  num_stays  income_total
# 1     1137041852.3226352       2899       14791.2
# 2     1148666757.7153966       2639       14835.3
# 3     1306564567.8397522       5226       14843.9
# 4     1446882218.0239325       5608       14811.8

# %%
test.head()
# Out:
#             0                      1                           2  \
# 0        Date  TotalAirlineTripstoDC  TotalAirlinePassengerstoDC
# 1  2022-01-01                    904                   1893198.0
# 2  2022-02-01                    830                   2139952.0
# 3  2022-03-01                    896                   3059442.0
# 4  2022-04-01                    858                   3272280.0
#
#                         3                              4  \
# 0  TotalAmericanTravelers  PercentofAmericanswhoTraveled
# 1      259584735.82010934              82.00471558566778
# 2      260109791.61199838              82.15668408700547
# 3      262116683.06916347              81.89755485680998
# 4      261462761.25324675              81.90694228417173
#
#                        5          6             7
# 0  TotalTripsbyAmericans  num_stays  income_total
# 1     1243775232.8225882       4356       15137.7
# 2     1210049335.9942613       4413       15125.6
# 3     1218479734.1890206       7754       15064.1
# 4     1279973330.1118326       9208       15055.2

# %%
train= train.drop(0)
train.head()
# Out:
#             0    1          2                   3                  4  \
# 1  2019-01-01  435  1326271.0  265224073.85258028  81.44242073648299
# 2  2019-02-01  385  1261292.0  266240835.73305443  81.77432628778035
# 3  2019-03-01  422  1668002.0  265091945.14415318  81.79908504520232
# 4  2019-04-01  427  1681832.0  264062598.41495603  81.35434739932987
# 5  2019-05-01  439  1766148.0  266133995.63478008    81.884669739372
#
#                     5     6        7
# 1  1137041852.3226352  2899  14791.2
# 2  1148666757.7153966  2639  14835.3
# 3  1306564567.8397522  5226  14843.9
# 4  1446882218.0239325  5608  14811.8
# 5  1415056833.4654295  6110  14814.7

# %%
test=test.drop(0)
test.head()
# Out:
#             0    1          2                   3                  4  \
# 1  2022-01-01  904  1893198.0  259584735.82010934  82.00471558566778
# 2  2022-02-01  830  2139952.0  260109791.61199838  82.15668408700547
# 3  2022-03-01  896  3059442.0  262116683.06916347  81.89755485680998
# 4  2022-04-01  858  3272280.0  261462761.25324675  81.90694228417173
# 5  2022-05-01  902  3415990.0  261053979.76624453  82.05992072229897
#
#                     5      6        7
# 1  1243775232.8225882   4356  15137.7
# 2  1210049335.9942613   4413  15125.6
# 3  1218479734.1890206   7754  15064.1
# 4  1279973330.1118326   9208  15055.2
# 5    1305916298.96838  10146  15036.4

# %%
train.to_csv('train_new.csv', index=False)

train_new = 'train_new.csv'

# %%
test.to_csv('test_new.csv', index=False)

test_new ='test_new.csv'

# %%
bucket_name = 'aurelia-resort-data'
s3_prefix = 'XGboost Forecast'

train_data_location = sagemaker_session.upload_data('train_new.csv', bucket=bucket_name, key_prefix=s3_prefix+'/train')
validation_data_location = sagemaker_session.upload_data('test_new.csv', bucket=bucket_name, key_prefix=s3_prefix+'/test')

# %%
# hyperparameters = {
#     'max_depth': '5',
#     'eta': '0.1',
#     'gamma': '1',
#     'min_child_weight': '1',
#     'subsample': '0.8',
#     'objective': 'reg:squarederror',
#     'num_round': '50'
# }

# %%
# xgb_estimator.set_hyperparameters(
#     objective='reg:squarederror',
#     max_depth=5,
#     eta=0.2,
#     gamma=4,
#     min_child_weight=6,
#     subsample=0.8,
#     silent=0,
#     num_round=100
# )

# %%
# train_input = sagemaker.inputs.TrainingInput(
#     f's3://aurelia-resort-data/model_train/data_csv/train.csv', 
#     content_type='csv'
# )

# %%
# train_input = sagemaker.inputs.TrainingInput(
#     f's3://aurelia-resort-data/XGboost Forecast/train/train_new.csv', 
#     content_type='csv'
# )

container = get_image_uri(region_name=region, 
                          repo_name='xgboost', 
                          repo_version='latest')

xgb_estimator = sagemaker.estimator.Estimator(container,
                                              role=sagemaker.get_execution_role(),
                                              instance_count=1,
                                              instance_type='ml.m4.xlarge',
                                              output_path=f's3://aurelia-resort-data/model_train/XGboost Forecast//output',
                                              sagemaker_session=sagemaker_session,)

xgb_estimator.set_hyperparameters(max_depth=5,
                                  eta=0.2,
                                  gamma=4,
                                  min_child_weight=6,
                                  subsample=0.8,
                                  objective='reg:linear',
                                  num_round=100)

train_input = sagemaker.inputs.TrainingInput(
    f's3://aurelia-resort-data/XGboost Forecast/train/train_new.csv', 
    content_type='csv'
)


test_input = sagemaker.inputs.TrainingInput(
    f's3://aurelia-resort-data/XGboost Forecast/test/test_new.csv', 
    content_type='csv'
)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
xgb_estimator.fit(inputs={'train': train_input, 'validation': test_input})

# xgb_estimator.fit({'train': train_input})
# Out:
# 2023-04-03 23:25:52 Starting - Starting the training job...
# 2023-04-03 23:26:17 Starting - Preparing the instances for trainingProfilerReport-1680564352: InProgress
# .........
# 2023-04-03 23:27:37 Downloading - Downloading input data...
# 2023-04-03 23:28:17 Training - Downloading the training image...
# 2023-04-03 23:28:48 Training - Training image download completed. Training in progress...Arguments: train
# [2023-04-03:23:29:02:INFO] Running standalone xgboost training.
# [2023-04-03:23:29:02:INFO] File size need to be processed in the node: 0.0mb. Available memory size in the node: 8606.14mb
# [2023-04-03:23:29:02:INFO] Determined delimiter of CSV input is ','
# [23:29:02] S3DistributionType set as FullyReplicated
# [23:29:02] 25x7 matrix with 175 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2023-04-03:23:29:02:INFO] Determined delimiter of CSV input is ','
# [23:29:02] S3DistributionType set as FullyReplicated
# [23:29:02] 7x7 matrix with 49 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [0]#011train-rmse:1628.52#011validation-rmse:1545.15
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [1]#011train-rmse:1322.07#011validation-rmse:1270.6
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [2]#011train-rmse:1098.78#011validation-rmse:1082.27
# [3]#011train-rmse:920.49#011validation-rmse:944.047
# [4]#011train-rmse:766.97#011validation-rmse:838.996
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [5]#011train-rmse:662.066#011validation-rmse:757.522
# [6]#011train-rmse:570.486#011validation-rmse:714.899
# [7]#011train-rmse:510.024#011validation-rmse:671.586
# [8]#011train-rmse:459.909#011validation-rmse:661.77
# [9]#011train-rmse:427.563#011validation-rmse:639.339
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10]#011train-rmse:401.925#011validation-rmse:643.016
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [11]#011train-rmse:386.308#011validation-rmse:649.392
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [12]#011train-rmse:374.023#011validation-rmse:639.857
# [13]#011train-rmse:363.302#011validation-rmse:626.092
# [14]#011train-rmse:355.393#011validation-rmse:613.589
# [15]#011train-rmse:348.342#011validation-rmse:603.13
# [16]#011train-rmse:346.024#011validation-rmse:613.767
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [17]#011train-rmse:344.585#011validation-rmse:623.65
# [18]#011train-rmse:338.814#011validation-rmse:613.08
# [19]#011train-rmse:333.867#011validation-rmse:600.765
# [20]#011train-rmse:328.018#011validation-rmse:586.079
# [21]#011train-rmse:324.273#011validation-rmse:575.314
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [22]#011train-rmse:320.092#011validation-rmse:564.567
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23]#011train-rmse:313.7#011validation-rmse:551.983
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [24]#011train-rmse:308.447#011validation-rmse:541.372
# [25]#011train-rmse:304.044#011validation-rmse:534.874
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [26]#011train-rmse:300.706#011validation-rmse:526.357
# [27]#011train-rmse:296.628#011validation-rmse:522.468
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [28]#011train-rmse:293.14#011validation-rmse:514.196
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [29]#011train-rmse:286.588#011validation-rmse:501.049
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [30]#011train-rmse:283.072#011validation-rmse:493.658
# [31]#011train-rmse:278.78#011validation-rmse:484.405
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [32]#011train-rmse:275.14#011validation-rmse:477.464
# [33]#011train-rmse:269.806#011validation-rmse:468.843
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [34]#011train-rmse:264.893#011validation-rmse:462.159
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [35]#011train-rmse:261.702#011validation-rmse:455.638
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [36]#011train-rmse:257.903#011validation-rmse:451.157
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [37]#011train-rmse:258.696#011validation-rmse:462.52
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [38]#011train-rmse:255.855#011validation-rmse:456.345
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [39]#011train-rmse:253.577#011validation-rmse:447.256
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [40]#011train-rmse:248.817#011validation-rmse:440.723
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [41]#011train-rmse:245.17#011validation-rmse:433
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [42]#011train-rmse:242.618#011validation-rmse:424.538
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [43]#011train-rmse:240.154#011validation-rmse:419.447
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [44]#011train-rmse:234.369#011validation-rmse:411.543
# [23:29:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
#