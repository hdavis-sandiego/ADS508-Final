# %% [markdown]
# ### XGBOOST Forecasting

# %%
import boto3
import sagemaker
import csv
import pandas as pd
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.amazon.amazon_estimator import get_image_uri

# xgb_estimator = sagemaker.estimator.Estimator(
#     image_uri='811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
#     role=sagemaker.get_execution_role(),
#     instance_count=1,
#     instance_type='ml.m5.large',
#     output_path=f's3://aurelia-resort-data/model_train/XGboost Forecast//output',
#     sagemaker_session=sagemaker_session,
#     framework_version='1.3-1'
# )

sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)

# %%
xgb_image_uri = sagemaker.image_uris.retrieve("xgboost", region="us-east-1", version="latest")

print(xgb_image_uri)
# Out:
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest

# %%
container = get_image_uri(region_name=region, 
                          repo_name='xgboost', 
                          repo_version='latest')

xgb_estimator = sagemaker.estimator.Estimator(container,
                                              role=sagemaker.get_execution_role(),
                                              instance_count=1,
                                              instance_type='ml.m4.xlarge',
                                              output_path=f's3://aurelia-resort-data/model_train/XGboost Forecast//output',
                                              sagemaker_session=sagemaker_session,)

xgb_estimator.set_hyperparameters(max_depth=5,
                                  eta=0.2,
                                  gamma=4,
                                  min_child_weight=6,
                                  subsample=0.8,
                                  objective='reg:squarederror',
                                  num_round=100)

# xgb_estimator.fit(inputs={'train': train_data})
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Get train/test dataframes from S3

# %%
# !aws s3 cp --recursive s3://aurelia-resort-data/model_train/data_csv/ ./data
# Out:
# download: s3://aurelia-resort-data/model_train/data_csv/train.csv to data/train.csv
# download: s3://aurelia-resort-data/model_train/data_csv/test_nans.csv to data/test_nans.csv
# download: s3://aurelia-resort-data/model_train/data_csv/test.csv to data/test.csv
# download: s3://aurelia-resort-data/model_train/data_csv/train_nans.csv to data/train_nans.csv

# %%
train = pd.read_csv('data/train.csv',  header=None)
test = pd.read_csv('data/test.csv', header=None)

# %%
train.head()
# Out:
#             0                      1                           2  \
# 0        Date  TotalAirlineTripstoDC  TotalAirlinePassengerstoDC
# 1  2019-01-01                    435                   1326271.0
# 2  2019-02-01                    385                   1261292.0
# 3  2019-03-01                    422                   1668002.0
# 4  2019-04-01                    427                   1681832.0
#
#                         3                              4  \
# 0  TotalAmericanTravelers  PercentofAmericanswhoTraveled
# 1       791536531.8525803              81.42464086737007
# 2       794586299.0187687              81.75514511420499
# 3         791140769.53125               81.7730402750601
# 4        788060775.614956              81.32895739711851
#
#                        5          6             7
# 0  TotalTripsbyAmericans  num_stays  income_total
# 1      3411167477.161345       2899       14791.2
# 2     3446039943.7153964       2639       14835.3
# 3     3919756293.4526553       5226       14843.9
# 4      4340727403.623933       5608       14811.8

# %%
test.head()
# Out:
#             0                      1                           2  \
# 0        Date  TotalAirlineTripstoDC  TotalAirlinePassengerstoDC
# 1  2022-01-01                    452                    946599.0
# 2  2022-02-01                    415                   1069976.0
# 3  2022-03-01                    448                   1529721.0
# 4  2022-04-01                    429                   1636140.0
#
#                         3                              4  \
# 0  TotalAmericanTravelers  PercentofAmericanswhoTraveled
# 1       772011110.2072061              81.95210153477797
# 2       773009379.8977127              82.09882819173558
# 3       776089362.1014216              81.84397060004146
# 4         776088311.58658               81.8549480812831
#
#                        5          6             7
# 0  TotalTripsbyAmericans  num_stays  income_total
# 1      3852407610.435491       4356       15137.7
# 2      3757569179.779976       4413       15125.6
# 3      3843540127.543859       7754       15064.1
# 4      3993424870.911833       9208       15055.2

# %%
train= train.drop(0)
train.head()
# Out:
#             0    1          2                  3                  4  \
# 1  2019-01-01  435  1326271.0  791536531.8525803  81.42464086737007
# 2  2019-02-01  385  1261292.0  794586299.0187687  81.75514511420499
# 3  2019-03-01  422  1668002.0    791140769.53125   81.7730402750601
# 4  2019-04-01  427  1681832.0   788060775.614956  81.32895739711851
# 5  2019-05-01  439  1766148.0  794267531.6992962  81.86138849687315
#
#                     5     6        7
# 1   3411167477.161345  2899  14791.2
# 2  3446039943.7153964  2639  14835.3
# 3  3919756293.4526553  5226  14843.9
# 4   4340727403.623933  5608  14811.8
# 5  4245220637.0138164  6110  14814.7

# %%
test=test.drop(0)
test.head()
# Out:
#             0    1          2                  3                  4  \
# 1  2022-01-01  452   946599.0  772011110.2072061  81.95210153477797
# 2  2022-02-01  415  1069976.0  773009379.8977127  82.09882819173558
# 3  2022-03-01  448  1529721.0  776089362.1014216  81.84397060004146
# 4  2022-04-01  429  1636140.0    776088311.58658   81.8549480812831
# 5  2022-05-01  451  1707995.0  777826533.8307607  82.01059959761147
#
#                     5      6        7
# 1   3852407610.435491   4356  15137.7
# 2   3757569179.779976   4413  15125.6
# 3   3843540127.543859   7754  15064.1
# 4   3993424870.911833   9208  15055.2
# 5  4021791218.8393474  10146  15036.4

# %%
train.to_csv('train_new.csv', index=False)

train_new = 'train_new.csv'

# %%
test.to_csv('test_new.csv', index=False)

test_new ='test_new.csv'

# %%
bucket_name = 'aurelia-resort-data'
s3_prefix = 'XGboost Forecast'

train_data_location = sagemaker_session.upload_data('train_new.csv', bucket=bucket_name, key_prefix=s3_prefix+'/train')
validation_data_location = sagemaker_session.upload_data('test_new.csv', bucket=bucket_name, key_prefix=s3_prefix+'/test')

# %%
# hyperparameters = {
#     'max_depth': '5',
#     'eta': '0.1',
#     'gamma': '1',
#     'min_child_weight': '1',
#     'subsample': '0.8',
#     'objective': 'reg:squarederror',
#     'num_round': '50'
# }

# %%
# xgb_estimator.set_hyperparameters(
#     objective='reg:squarederror',
#     max_depth=5,
#     eta=0.2,
#     gamma=4,
#     min_child_weight=6,
#     subsample=0.8,
#     silent=0,
#     num_round=100
# )

# %%
# train_input = sagemaker.inputs.TrainingInput(
#     f's3://aurelia-resort-data/model_train/data_csv/train.csv', 
#     content_type='csv'
# )

# %%
# train_input = sagemaker.inputs.TrainingInput(
#     f's3://aurelia-resort-data/XGboost Forecast/train/train_new.csv', 
#     content_type='csv'
# )

container = get_image_uri(region_name=region, 
                          repo_name='xgboost', 
                          repo_version='latest')

xgb_estimator = sagemaker.estimator.Estimator(container,
                                              role=sagemaker.get_execution_role(),
                                              instance_count=1,
                                              instance_type='ml.m4.xlarge',
                                              output_path=f's3://aurelia-resort-data/model_train/XGboost Forecast//output',
                                              sagemaker_session=sagemaker_session,)

xgb_estimator.set_hyperparameters(max_depth=5,
                                  eta=0.2,
                                  gamma=4,
                                  min_child_weight=6,
                                  subsample=0.8,
                                  objective='reg:linear',
                                  num_round=100)

train_input = sagemaker.inputs.TrainingInput(
    f's3://aurelia-resort-data/XGboost Forecast/train/train_new.csv', 
    content_type='csv'
)


test_input = sagemaker.inputs.TrainingInput(
    f's3://aurelia-resort-data/XGboost Forecast/test/test_new.csv', 
    content_type='csv'
)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
xgb_estimator.fit(inputs={'train': train_input, 'validation': test_input})

# xgb_estimator.fit({'train': train_input})
# Out:
# 2023-04-10 06:07:36 Starting - Starting the training job...
# 2023-04-10 06:08:02 Starting - Preparing the instances for trainingProfilerReport-1681106856: InProgress
# .........
# 2023-04-10 06:09:29 Downloading - Downloading input data...
# 2023-04-10 06:10:01 Training - Downloading the training image...
# 2023-04-10 06:10:30 Training - Training image download completed. Training in progress...Arguments: train
# [2023-04-10:06:10:45:INFO] Running standalone xgboost training.
# [2023-04-10:06:10:45:INFO] File size need to be processed in the node: 0.0mb. Available memory size in the node: 8607.06mb
# [2023-04-10:06:10:45:INFO] Determined delimiter of CSV input is ','
# [06:10:45] S3DistributionType set as FullyReplicated
# [06:10:45] 37x7 matrix with 259 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2023-04-10:06:10:45:INFO] Determined delimiter of CSV input is ','
# [06:10:45] S3DistributionType set as FullyReplicated
# [06:10:45] 7x7 matrix with 49 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [0]#011train-rmse:1621.34#011validation-rmse:1529.19
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [1]#011train-rmse:1322.83#011validation-rmse:1265.62
# [2]#011train-rmse:1088.79#011validation-rmse:1072.57
# [3]#011train-rmse:889.803#011validation-rmse:924.509
# [4]#011train-rmse:746.244#011validation-rmse:809.091
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [5]#011train-rmse:621.393#011validation-rmse:742.371
# [6]#011train-rmse:526.791#011validation-rmse:704.794
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [7]#011train-rmse:458.663#011validation-rmse:687.201
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [8]#011train-rmse:413.322#011validation-rmse:658.479
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [9]#011train-rmse:375.082#011validation-rmse:637.647
# [10]#011train-rmse:347.107#011validation-rmse:641.872
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [11]#011train-rmse:331.996#011validation-rmse:628.812
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [12]#011train-rmse:316.936#011validation-rmse:617.61
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [13]#011train-rmse:303.701#011validation-rmse:606.943
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14]#011train-rmse:295.194#011validation-rmse:598.213
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [15]#011train-rmse:285.334#011validation-rmse:588.424
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [16]#011train-rmse:281.214#011validation-rmse:598.979
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [17]#011train-rmse:274.899#011validation-rmse:587.741
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [18]#011train-rmse:273.097#011validation-rmse:596.139
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [19]#011train-rmse:267.533#011validation-rmse:584.076
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [20]#011train-rmse:261.563#011validation-rmse:572.117
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [21]#011train-rmse:258.034#011validation-rmse:560.843
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [22]#011train-rmse:252.771#011validation-rmse:549.934
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23]#011train-rmse:249.383#011validation-rmse:539.106
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [24]#011train-rmse:244.469#011validation-rmse:529.658
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [25]#011train-rmse:241.572#011validation-rmse:519.537
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [26]#011train-rmse:236.618#011validation-rmse:510.916
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [27]#011train-rmse:231.032#011validation-rmse:501.394
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [28]#011train-rmse:228.1#011validation-rmse:492.478
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [29]#011train-rmse:223.447#011validation-rmse:480.963
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [30]#011train-rmse:219.341#011validation-rmse:471.96
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [31]#011train-rmse:215.526#011validation-rmse:464.461
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [32]#011train-rmse:211.446#011validation-rmse:456.753
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [33]#011train-rmse:207.486#011validation-rmse:447.702
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [34]#011train-rmse:203.642#011validation-rmse:440.499
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [35]#011train-rmse:200.476#011validation-rmse:431.655
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [36]#011train-rmse:197.308#011validation-rmse:424.14
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [37]#011train-rmse:194.138#011validation-rmse:416.123
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [38]#011train-rmse:191.213#011validation-rmse:408.419
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [39]#011train-rmse:187.24#011validation-rmse:400.105
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [40]#011train-rmse:183.718#011validation-rmse:391.941
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [41]#011train-rmse:180.91#011validation-rmse:383.387
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [42]#011train-rmse:177.424#011validation-rmse:375.99
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [43]#011train-rmse:176.951#011validation-rmse:382.213
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [06:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
#